# %% [markdown]
# <a href="https://colab.research.google.com/github/SYED-AZEES/project2/blob/main/newsih.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dat = pd.read_excel("newsih.xlsx", sheet_name="Sheet1")  # Replace "Sheet1" with the actual sheet name if different
dat
# Out:
#        Route_Id                                Starts From  \
# 0           108                     Hari Nagar Clock Tower
# 1       108 STL                                Nehru Vihar
# 2           185                Nathupura Crossing Terminal
# 3   185 Lnk STL                          BBM Cluster Depot
# 4       185 STL                          BBM Cluster Depot
# 5           185                          Kendriya Terminal
# 6        234 CL                                Harsh Vihar
# 7           262                                Harsh Vihar
# 8   262 Lnk STL                          BBM Cluster Depot
# 9            78                      Inderpuri Krishi Kunj
# 10          719                           Pandwala Village
# 11          720                     JanakPuri B-1 Terminal
# 12          723                       Mangla Puri Terminal
# 13        743 A            Bharthal Village (Shyam Mandir)
# 14      743 STL                        Dichaon Kalan Depot
# ...

# %%
routearr=dat['Route_Id']
routearr
# Out:
# 0             108
# 1         108 STL
# 2             185
# 3     185 Lnk STL
# 4         185 STL
# 5             185
# 6          234 CL
# 7             262
# 8     262 Lnk STL
# 9              78
# 10            719
# 11            720
# 12            723
# 13          743 A
# 14        743 STL
# 15          405 A
# 16            405
# 17          418 A
# 18          418 A
# 19            480
# 20         507 CL
# 21        522 STL
# 22        543 STL
# 23         47 ACL
# 24      511 A STL
# 25         540 CL
# 26         548 CL
# 27          717 A
# 28    411 Lnk STL
# 29    433 Lnk STL
# 30            717
# 31            764
# 32            794
# 33          157 A
# 34            165
# 35            212
# 36            236
# 37            261
# 38        309 EXT
# 39       419L STL
# 40     73 Lnk STL
# 41             85
# 42          871 A
# 43            871
# 44            143
# 45            205
# 46            208
# 47            310
# 48             73
# 49            847
# ...

# %%
dem=dat['Demand'].tolist()
print(dem)
# Out:
# [800, 500, 1200, 300, 600, 1000, 1100, 900, 200, 600, 800, 1000, 900, 400, 500, 900, 800, 1000, 900, 700, 800, 600, 500, 1000, 400, 600, 800, 900, 500, 600, 800, 1000, 900, 700, 1200, 1000, 900, 700, 400, 600, 500, 900, 600, 700, 1000, 600, 700, 600, 800, 1200, 800, 1000, 700, 900, 600, 500, 400, 900, 800, 1000]

# %%
period=dat['Duration']
period
# Out:
# 0     45
# 1     20
# 2     60
# 3     25
# 4     30
# 5     55
# 6     65
# 7     50
# 8     15
# 9     30
# 10    40
# 11    70
# 12    60
# 13    40
# 14    35
# 15    45
# 16    50
# 17    55
# 18    55
# 19    45
# 20    50
# 21    25
# 22    30
# 23    60
# 24    20
# 25    40
# 26    50
# 27    60
# 28    35
# 29    45
# 30    50
# 31    65
# 32    55
# 33    50
# 34    70
# 35    60
# 36    55
# 37    45
# 38    35
# 39    40
# 40    30
# 41    60
# 42    40
# 43    45
# 44    65
# 45    40
# 46    50
# 47    50
# 48    55
# 49    70
# 50    55
# 51    65
# 52    50
# 53    60
# 54    35
# 55    40
# 56    30
# 57    55
# 58    50
# 59    60
# Name: Duration, dtype: int64

# %%
#routearr=[1,2,3,4,5,6]
#demand=[4126,3497,11030,3029,3836,1111]
# Use the built-in sum function
totaldemand = sum(dem) # this will now call the built-in sum function
#period=[30,45,45,60,75,75]
per=[0.4,0.2,0.35,0.05]
shift=[195,360,240,90]
p=[]
print(totaldemand)
# Out:
# 45200

# %%
n = len(period)
m = len(shift)
T = []
for i in range(n):
    T.append([0] * m)
for i in range(len(period)):
    for j in range(len(shift)):
        if(j%2!=0):
            T[i][j]=int(shift[j]/period[i])
        else:
            T[i][j]=int(shift[j]/period[i])+1
ttf=0
print("trip factor for route i and shift j")
print("rno   t1 t2 t3 t4")
nonn=pd.DataFrame(T)
print(nonn)
# Out:
# trip factor for route i and shift j
# rno   t1 t2 t3 t4
#      0   1   2  3
# 0    5   8   6  2
# 1   10  18  13  4
# 2    4   6   5  1
# 3    8  14  10  3
# 4    7  12   9  3
# 5    4   6   5  1
# 6    4   5   4  1
# 7    4   7   5  1
# 8   14  24  17  6
# 9    7  12   9  3
# 10   5   9   7  2
# 11   3   5   4  1
# 12   4   6   5  1
# 13   5   9   7  2
# 14   6  10   7  2
# 15   5   8   6  2
# 16   4   7   5  1
# 17   4   6   5  1
# 18   4   6   5  1
# 19   5   8   6  2
# 20   4   7   5  1
# 21   8  14  10  3
# 22   7  12   9  3
# 23   4   6   5  1
# 24  10  18  13  4
# 25   5   9   7  2
# 26   4   7   5  1
# 27   4   6   5  1
# 28   6  10   7  2
# 29   5   8   6  2
# 30   4   7   5  1
# 31   4   5   4  1
# 32   4   6   5  1
# 33   4   7   5  1
# 34   3   5   4  1
# 35   4   6   5  1
# 36   4   6   5  1
# 37   5   8   6  2
# 38   6  10   7  2
# 39   5   9   7  2
# 40   7  12   9  3
# 41   4   6   5  1
# 42   5   9   7  2
# 43   5   8   6  2
# 44   4   5   4  1
# 45   5   9   7  2
# ...

# %%
ttf
# Out:
# 1284

# %%
for i in range(len(dem)):
    s=round((dem[i]/totaldemand),3)
    p.append(s)
print("trip portion of each route")
print(p)
print()
# Out:
# trip portion of each route
# [0.018, 0.011, 0.027, 0.007, 0.013, 0.022, 0.024, 0.02, 0.004, 0.013, 0.018, 0.022, 0.02, 0.009, 0.011, 0.02, 0.018, 0.022, 0.02, 0.015, 0.018, 0.013, 0.011, 0.022, 0.009, 0.013, 0.018, 0.02, 0.011, 0.013, 0.018, 0.022, 0.02, 0.015, 0.027, 0.022, 0.02, 0.015, 0.009, 0.013, 0.011, 0.02, 0.013, 0.015, 0.022, 0.013, 0.015, 0.013, 0.018, 0.027, 0.018, 0.022, 0.015, 0.02, 0.013, 0.011, 0.009, 0.02, 0.018, 0.022]

# %%
#routearr=[1,2,3,4,5,6]
#demand=[4126,3497,11030,3029,3836,1111]
# Use the built-in sum function
totaldemand = sum(dem) # this will now call the built-in sum function
#period=[30,45,45,60,75,75]
per=[0.4,0.2,0.35,0.05]
shift=[195,360,240,90]
p=[]
print(totaldemand)

n = len(period) # n is the length of period list which is 60 in this case
m = len(shift)
T = []
for i in range(n):
    T.append([0] * m)
for i in range(len(period)):
    for j in range(len(shift)):
        if(j%2!=0):
            T[i][j]=int(shift[j]/period[i])
        else:
            T[i][j]=int(shift[j]/period[i])+1
ttf=0
print("trip factor for route i and shift j")
print("rno   t1 t2 t3 t4")
nonn=pd.DataFrame(T)
print(nonn)


ttf

for i in range(len(dem)): # Calculate p based on dem
    s=round((dem[i]/totaldemand),3)
    p.append(s)
print("trip portion of each route")
print(p)
print()

notps = []
for i in range(len(dem)): # Iterate through the length of dem (same as p) instead of n
    notps.append([0] * m)
for i in range(len(dem)): # Iterate through the length of dem (same as p) instead of n
    a=(ttf*p[i])
    for j in range(m):
        if(j%2!=0):
            notps[i][j]=int(round(a*per[j]))
        else:
            notps[i][j]=int(round(a*per[j]))+1

print("no of trips per route per shift")
print("rno     s1           s2            s3           s4")
for i in range(len(dem)): # Iterate through the length of dem instead of n
    for j in range(m):
        if(j==0):
             print(i+1,"     ",notps[i][j],end="           ")
        else:
             print(notps[i][j],end="            ")
    print()
print()
# Out:
# 45200
# trip factor for route i and shift j
# rno   t1 t2 t3 t4
#      0   1   2  3
# 0    5   8   6  2
# 1   10  18  13  4
# 2    4   6   5  1
# 3    8  14  10  3
# 4    7  12   9  3
# 5    4   6   5  1
# 6    4   5   4  1
# 7    4   7   5  1
# 8   14  24  17  6
# 9    7  12   9  3
# 10   5   9   7  2
# 11   3   5   4  1
# 12   4   6   5  1
# 13   5   9   7  2
# 14   6  10   7  2
# 15   5   8   6  2
# 16   4   7   5  1
# 17   4   6   5  1
# 18   4   6   5  1
# 19   5   8   6  2
# 20   4   7   5  1
# 21   8  14  10  3
# 22   7  12   9  3
# 23   4   6   5  1
# 24  10  18  13  4
# 25   5   9   7  2
# 26   4   7   5  1
# 27   4   6   5  1
# 28   6  10   7  2
# 29   5   8   6  2
# 30   4   7   5  1
# 31   4   5   4  1
# 32   4   6   5  1
# 33   4   7   5  1
# 34   3   5   4  1
# 35   4   6   5  1
# 36   4   6   5  1
# 37   5   8   6  2
# 38   6  10   7  2
# 39   5   9   7  2
# 40   7  12   9  3
# 41   4   6   5  1
# 42   5   9   7  2
# 43   5   8   6  2
# 44   4   5   4  1
# ...

# %%
nobuses=[]
for i in range(n):
    nobuses.append([0]*m)
for i in range(n):
    for j in range(m):
        d=T[i][j]
        try:
            if(j%2!=0):
              if(notps[i][j]/d<1):
                nobuses[i][j]=round(notps[i][j]/d)+1
              else:
                nobuses[i][j]=round(notps[i][j]/d)
            elif(j==2):
              if(notps[i][j]/d<1):
                nobuses[i][j]=round(notps[i][j]/d)+1
              else:
                nobuses[i][j]=round(notps[i][j]/d)
            else:
                nobuses[i][j]=round(notps[i][j]/d)+1

        except:
            print()
totbuses=0
print("no of buses per route per shift")
print("rno     s1           s2          s3           s4")
for i in range(n):
    for j in range(m):
        if(j==0):
             print(i+1,"    ",nobuses[i][j],end="            ")
        else:
             print(nobuses[i][j],end="            ")
        totbuses=totbuses+nobuses[i][j]


    print()
# Out:
# no of buses per route per shift
# rno     s1           s2          s3           s4
# 1      3            2            2            1
# 2      2            1            1            1
# 3      5            1            3            2
# 4      2            1            1            1
# 5      2            1            2            1
# 6      4            1            2            1
# 7      4            1            3            2
# 8      4            2            2            1
# 9      1            1            1            1
# 10      2            1            2            1
# 11      3            2            1            1
# 12      5            1            3            1
# 13      4            2            2            1
# 14      2            1            2            1
# 15      2            1            2            1
# 16      3            2            2            1
# 17      3            2            2            1
# 18      4            1            2            1
# ...

# %%
# It appears that the sum function has been overwritten
# Delete the sum variable to restore the built-in sum function
del sum

nobuses=pd.DataFrame(nobuses)
nobuses.to_excel("totbuses.xlsx")

# Use the built-in sum function
totb=sum(nobuses[0]+nobuses[1])
print(totb)
print(nobuses)
# Out:
# 273
#     0  1  2  3
# 0   3  2  2  1
# 1   2  1  1  1
# 2   5  1  3  2
# 3   2  1  1  1
# 4   2  1  2  1
# 5   4  1  2  1
# 6   4  1  3  2
# 7   4  2  2  1
# 8   1  1  1  1
# 9   2  1  2  1
# 10  3  2  1  1
# 11  5  1  3  1
# 12  4  2  2  1
# 13  2  1  2  1
# 14  2  1  2  1
# 15  3  2  2  1
# 16  3  2  2  1
# 17  4  1  2  1
# 18  4  2  2  1
# 19  3  1  1  1
# 20  3  2  2  1
# 21  2  1  2  1
# 22  2  1  2  1
# 23  4  1  2  1
# 24  2  1  1  1
# 25  3  1  1  1
# 26  3  2  2  1
# 27  4  2  2  1
# 28  2  1  2  1
# 29  3  1  1  1
# 30  3  2  2  1
# 31  4  1  3  1
# 32  4  2  2  1
# 33  3  2  2  1
# 34  6  1  3  2
# 35  4  1  2  1
# 36  4  2  2  1
# 37  3  1  1  1
# 38  2  1  2  1
# 39  3  1  1  1
# 40  2  1  2  1
# 41  4  2  2  1
# 42  3  1  1  1
# 43  3  1  1  1
# 44  4  1  3  1
# 45  3  1  1  1
# 46  3  2  2  1
# 47  3  1  1  1
# 48  3  2  2  1
# 49  6  1  3  2
# 50  3  2  2  1
# 51  4  1  3  1
# 52  3  2  2  1
# 53  4  2  2  1
# 54  2  1  1  1
# 55  2  1  2  1
# 56  2  1  2  1
# ...

# %%
totb
# Out:
# 273

# %%
totaldemand
# Out:
# 45200

# %%
#if we do manually alloaction of buses to the route
MA=totaldemand/60
print(round(MA))
# Out:
# 753

# %%
#part2
duration=dat['Duration'].tolist()
duration
print(duration)
from collections import Counter
counts = Counter(duration)

print(counts)
# Out:
# [45, 20, 60, 25, 30, 55, 65, 50, 15, 30, 40, 70, 60, 40, 35, 45, 50, 55, 55, 45, 50, 25, 30, 60, 20, 40, 50, 60, 35, 45, 50, 65, 55, 50, 70, 60, 55, 45, 35, 40, 30, 60, 40, 45, 65, 40, 50, 50, 55, 70, 55, 65, 50, 60, 35, 40, 30, 55, 50, 60]
# Counter({50: 10, 60: 8, 55: 8, 40: 7, 45: 6, 30: 5, 65: 4, 35: 4, 70: 3, 20: 2, 25: 2, 15: 1})

# %%
routes=dat['Route_Id'].tolist()
print(routes)
# Out:
# [108, '108 STL', 185, '185 Lnk STL', '185 STL', 185, '234 CL', 262, '262 Lnk STL', 78, 719, 720, 723, '743 A', '743 STL', '405 A', 405, '418 A', '418 A', 480, '507 CL', '522 STL', '543 STL', '47 ACL', '511 A STL', '540 CL', '548 CL', '717 A', '411 Lnk STL', '433 Lnk STL', 717, 764, 794, '157 A', 165, 212, 236, 261, '309 EXT', '419L STL', '73 Lnk STL', 85, '871 A', 871, 143, 205, 208, 310, 73, 847, '88 A', '932 A', 997, '181 A', '214CL', '214CL', '405 STL', 721, 727, 604]

# %%
noofbuses=[]
for i in range(len(routes)):
  sum=0
  for j in range(2):
    # Accessing the DataFrame "nobuses" correctly using .iloc[]
    sum=sum+nobuses.iloc[i,j] # Use .iloc[] to access elements by integer index
  noofbuses.append(sum)
print(noofbuses)
print(len(noofbuses))
# Out:
# [5, 3, 6, 3, 3, 5, 5, 6, 2, 3, 5, 6, 6, 3, 3, 5, 5, 5, 6, 4, 5, 3, 3, 5, 3, 4, 5, 6, 3, 4, 5, 5, 6, 5, 7, 5, 6, 4, 3, 4, 3, 6, 4, 4, 5, 4, 5, 4, 5, 7, 5, 5, 5, 6, 3, 3, 3, 6, 5, 5]
# 60

# %%
drivers = [
    "FAIZAN", "AZEES", "DIVYA", "BHAVITA", "AMAR", "BHAVANA", "Ananya", "Arjun", "Ashi", "Avni",
    "Bhavesh", "Chaitanya", "Chandni", "Deepak", "Diya", "Ekta", "Gaurav", "Ishaan", "Jaya", "Kartik",
    "Kavya", "Kiran", "Kriti", "Lakshmi", "Madhav", "Meera", "Mihir", "Naina", "Nikhil", "Pallavi",
    "Ravi", "Riya", "Rohan", "Saanvi", "Sachin", "Sagar", "Saloni", "Sanjay", "Sneha", "Sourabh",
    "Tanuja", "Tarun", "Vansh", "Vijay", "Vidya", "Vikram", "Yash", "Aditi", "Ajeet", "Akanksha",
    "Amit", "Anil", "Anju", "Aparna", "Ashok", "Avinash", "Chirag", "Deepali", "Devesh", "Divya",
    "Esha", "Gita", "Gulshan", "Hemant", "Hina", "Ishita", "Jitendra", "Kavita", "Kunal", "Maya",
    "Nandini", "Neelam", "Nilesh", "Pooja", "Prakash", "Rachna", "Rajeev", "Ramesh", "Ritika", "Rohit",
    "Ruchi", "Sandeep", "Sanjana", "Siddharth", "Sonali", "Suman", "Surbhi", "Swati", "Tanvi", "Tushar",
    "Usha", "Vandana", "Vikrant", "Yogesh", "Zoya", "Abhishek", "Aishwarya", "Ankit", "Aparajita", "Arun",
    "Bharat", "Charul", "Chinmay", "Dharmendra", "Gauravi", "Gunjan", "Harsimran", "Indira", "Jaspreet", "Jitendra",
    "Kalpana", "Kashish", "Kriti", "Lalita", "Mahesh", "Manisha", "Meenal", "Minal", "Namrata", "Nirav",
    "Palak", "Pankaj", "Parul", "Priti", "Raman", "Ritika", "Rupali", "Sakshi", "Sandeep", "Sanjay",
    "Sanjita", "Sarika", "Shalini", "Sharad", "Shivani", "Shweta", "Snehal", "Sonu", "Suman", "Sweta",
    "Tanya", "Tejas", "Trisha", "Tulika", "Vijay", "Vishal", "Yamini", "Aarav", "Aishwarya", "Ansh",
    "Arjun", "Arya", "Chandan", "Chaya", "Diksha", "Gaurav", "Ishaan", "Jaya", "Kartik", "Kriti",
    "Lakshmi", "Manoj", "Maya", "Meera", "Mihir", "Naina", "Nikhil", "Pallavi", "Ravi", "Riya",
    "Rohit", "Saanvi", "Siddharth", "Sneha", "Sourabh", "Tanuja", "Tarun", "Vansh", "Vidya", "Vikram",
    "Yash", "Aaravi", "Aditi", "Ajeet", "Amit", "Anil", "Anju", "Aparna", "Ashok", "Avinash",
    "Chirag", "Deepali", "Devesh", "Divya", "Esha", "Gita", "Gulshan", "Hemant", "Hina", "Ishita",
    "Jitendra", "Kavita", "Kunal", "Maya", "Nandini", "Neelam", "Nilesh", "Pooja", "Prakash", "Rachna",
    "Rajeev", "Ramesh", "Ritika", "Rohit", "Ruchi", "Sandeep", "Sanjana", "Siddharth", "Sonali", "Suman",
    "Surbhi", "Swati", "Tanvi", "Tushar", "Usha", "Vandana", "Vikrant", "Yogesh", "Zoya", "Abhishek",
    "Aishwarya", "Ankit", "Aparajita", "Arun", "Bharat", "Charul", "Chinmay", "Dharmendra", "Gauravi", "Gunjan",
    "Harsimran", "Indira", "Jaspreet", "Jitendra", "Kalpana", "Kashish", "Kriti", "Lalita", "Mahesh", "Manisha",
    "Meenal", "Minal", "Namrata", "Nirav", "Palak", "Pankaj", "Parul", "Priti", "Raman", "Ritika",
    "Rupali", "Sakshi", "Sandeep", "Sanjay", "Sanjita", "Sarika", "Shalini", "Sharad", "Shivani", "Shweta",
    "Snehal", "Sonu", "Suman", "Sweta", "Tanya", "Tejas", "Trisha", "Tulika", "Vijay", "Vishal", "Yamini"
]

bu = []
routes
for i in range(len(routes)):
    a=noofbuses[i]+1
    bu.append([0] * a)
k=0
b=0
for i in range(len(routes)):
  for j in range(noofbuses[i]+1):
    if(j>0):
      bu[i][j]=drivers[k]
      k=k+1
    if(j==0):
      bu[i][j]=routes[b]
      b=b+1
print(bu)
# Out:
# [[108, 'FAIZAN', 'AZEES', 'DIVYA', 'BHAVITA', 'AMAR'], ['108 STL', 'BHAVANA', 'Ananya', 'Arjun'], [185, 'Ashi', 'Avni', 'Bhavesh', 'Chaitanya', 'Chandni', 'Deepak'], ['185 Lnk STL', 'Diya', 'Ekta', 'Gaurav'], ['185 STL', 'Ishaan', 'Jaya', 'Kartik'], [185, 'Kavya', 'Kiran', 'Kriti', 'Lakshmi', 'Madhav'], ['234 CL', 'Meera', 'Mihir', 'Naina', 'Nikhil', 'Pallavi'], [262, 'Ravi', 'Riya', 'Rohan', 'Saanvi', 'Sachin', 'Sagar'], ['262 Lnk STL', 'Saloni', 'Sanjay'], [78, 'Sneha', 'Sourabh', 'Tanuja'], [719, 'Tarun', 'Vansh', 'Vijay', 'Vidya', 'Vikram'], [720, 'Yash', 'Aditi', 'Ajeet', 'Akanksha', 'Amit', 'Anil'], [723, 'Anju', 'Aparna', 'Ashok', 'Avinash', 'Chirag', 'Deepali'], ['743 A', 'Devesh', 'Divya', 'Esha'], ['743 STL', 'Gita', 'Gulshan', 'Hemant'], ['405 A', 'Hina', 'Ishita', 'Jitendra', 'Kavita', 'Kunal'], [405, 'Maya', 'Nandini', 'Neelam', 'Nilesh', 'Pooja'], ['418 A', 'Prakash', 'Rachna', 'Rajeev', 'Ramesh', 'Ritika'], ['418 A', 'Rohit', 'Ruchi', 'Sandeep', 'Sanjana', 'Siddharth',
# ...

# %%
#allocation of drivers to the each route based on the buses
ADB=pd.DataFrame(bu)
ADB.to_excel("DriversAllocation.xlsx")
print("Drivers Allocation")
print("          routeno     Driver1    Driver2    Driver3   Driver4   Driver5   Driver6   Driver7")
ADB
# Out:
# Drivers Allocation
#           routeno     Driver1    Driver2    Driver3   Driver4   Driver5   Driver6   Driver7
#               0           1          2          3           4          5  \
# 0           108      FAIZAN      AZEES      DIVYA     BHAVITA       AMAR
# 1       108 STL     BHAVANA     Ananya      Arjun        None       None
# 2           185        Ashi       Avni    Bhavesh   Chaitanya    Chandni
# 3   185 Lnk STL        Diya       Ekta     Gaurav        None       None
# 4       185 STL      Ishaan       Jaya     Kartik        None       None
# 5           185       Kavya      Kiran      Kriti     Lakshmi     Madhav
# 6        234 CL       Meera      Mihir      Naina      Nikhil    Pallavi
# 7           262        Ravi       Riya      Rohan      Saanvi     Sachin
# 8   262 Lnk STL      Saloni     Sanjay       None        None       None
# 9            78       Sneha    Sourabh     Tanuja        None       None
# ...

# %%
noofbuses=[]
for i in range(len(routes)):
  sum=0
  for j in range(2,4):
    # Accessing the DataFrame "nobuses" correctly using .iloc[]
    sum=sum+nobuses.iloc[i,j] # Use .iloc[] to access elements by integer index
  noofbuses.append(sum)
print(noofbuses)
# Out:
# [3, 2, 5, 2, 3, 3, 5, 3, 2, 3, 2, 4, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 2, 2, 3, 3, 3, 2, 3, 4, 3, 3, 5, 3, 3, 2, 3, 2, 3, 3, 2, 2, 4, 2, 3, 2, 3, 5, 3, 4, 3, 3, 2, 3, 3, 3, 3, 3]
